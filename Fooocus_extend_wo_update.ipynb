# %% [markdown]
# <a href="https://colab.research.google.com/github/everscared/Fooocus/blob/main/Fooocus_extend_wo_update.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @markdown # Select profile of Fooocus and start/restart

Fooocus_Profile = "realistic" #@param ["default", "realistic", "anime"]
Fooocus_Theme = "dark" #@param ["dark", "light"]
Tunnel = "gradio" #@param ["gradio", "cloudflared"]

# !pip install pygit2==1.12.2
# %cd /content
# !git clone https://github.com/shaitanzx/Fooocus_extend.git
# !mkdir /content/Fooocus_extend/batch_images
if Tunnel=='cloudflared':
  # !wget https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
  # !dpkg -i cloudflared-linux-amd64.deb
  # %cd /content/Fooocus_extend
  # !wget -O /content/Fooocus_extend/patcher_tunel.py https://github.com/shaitanzx/Fooocus_extend/raw/main/patcher_tunel.py
  # !python /content/Fooocus_extend/patcher_tunel.py
  # !rm /content/Fooocus_extend/patcher_tunel.py

Memory_patch = True #@param {type:"boolean"}
patch=""
if Memory_patch == True :
    patch="--always-high-vram --all-in-fp16"

GoogleDrive_output = True #@param {type:"boolean"}
output_foder=""
if GoogleDrive_output == True :
    from google.colab import drive
    drive.mount('/content/drive', force_remount=True)
    output_foder="--output-path /content/drive/MyDrive/outputs"
    # !mkdir /content/drive/MyDrive/outputs

# %cd /content/Fooocus_extend
#run foocus
if Fooocus_Profile=='default':
  profile=""
if Fooocus_Profile=='realistic':
  profile="--preset realistic"
if Fooocus_Profile=='anime':
  profile="--preset anime"

if Fooocus_Theme=='dark':
  theme="--theme dark"
if Fooocus_Theme=='light':
  theme=""

# !python launch.py {profile} {theme} --share {patch} {output_foder}
# Out:
# Collecting pygit2==1.12.2
#   Downloading pygit2-1.12.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.5 kB)
# Requirement already satisfied: cffi>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from pygit2==1.12.2) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.9.1->pygit2==1.12.2) (2.22)
# Downloading pygit2-1.12.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 41.4 MB/s eta 0:00:00
# Installing collected packages: pygit2
#   Attempting uninstall: pygit2
#     Found existing installation: pygit2 1.16.0
#     Uninstalling pygit2-1.16.0:
#       Successfully uninstalled pygit2-1.16.0
# Successfully installed pygit2-1.12.2
# /content
# Cloning into 'Fooocus_extend'...
# remote: Enumerating objects: 7312, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 7312 (delta 19), reused 16 (delta 16), pack-reused 7279 (from 2)
# Receiving objects: 100% (7312/7312), 39.94 MiB | 25.34 MiB/s, done.
# Resolving deltas: 100% (4069/4069), done.
# Mounted at /content/drive
# mkdir: cannot create directory ‘/content/drive/MyDrive/outputs’: File exists
# /content/Fooocus_extend
# [System ARGV] ['launch.py', '--preset', 'realistic', '--theme', 'dark', '--share', '--always-high-vram', '--all-in-fp16', '--output-path', '/content/drive/MyDrive/outputs']
# Python 3.10.12 (main, Nov  6 2024, 20:22:13) [GCC 11.4.0]
# Fooocus version: 2.5.5
# Error checking version for torchsde: No package metadata was found for torchsde
# Installing requirements
# Loaded preset: /content/Fooocus_extend/presets/realistic.json
# Overriding config value path_outputs with /content/drive/MyDrive/outputs
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/xlvaeapp.pth" to /content/Fooocus_extend/models/vae_approx/xlvaeapp.pth
#
# 100% 209k/209k [00:00<00:00, 10.0MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/vaeapp_sd15.pt" to /content/Fooocus_extend/models/vae_approx/vaeapp_sd15.pth
#
# 100% 209k/209k [00:00<00:00, 8.88MB/s]
# Downloading: "https://huggingface.co/mashb1t/misc/resolve/main/xl-to-v1_interposer-v4.0.safetensors" to /content/Fooocus_extend/models/vae_approx/xl-to-v1_interposer-v4.0.safetensors
#
# 100% 5.40M/5.40M [00:00<00:00, 44.8MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/fooocus_expansion.bin" to /content/Fooocus_extend/models/prompt_expansion/fooocus_expansion/pytorch_model.bin
#
# 100% 335M/335M [00:01<00:00, 222MB/s]
# Downloading: "https://huggingface.co/lllyasviel/fav_models/resolve/main/fav/realisticStockPhoto_v20.safetensors" to /content/Fooocus_extend/models/checkpoints/realisticStockPhoto_v20.safetensors
#
# 100% 6.46G/6.46G [00:49<00:00, 139MB/s]
# Downloading: "https://huggingface.co/mashb1t/fav_models/resolve/main/fav/SDXL_FILM_PHOTOGRAPHY_STYLE_V1.safetensors" to /content/Fooocus_extend/models/loras/SDXL_FILM_PHOTOGRAPHY_STYLE_V1.safetensors
#
# 100% 870M/870M [00:21<00:00, 42.1MB/s]
# Total VRAM 15102 MB, total RAM 12979 MB
# Forcing FP16.
# Set vram state to: HIGH_VRAM
# Always offload VRAM
# Device: cuda:0 Tesla T4 : native
# VAE dtype: torch.float32
# Using pytorch cross attention
# Refiner unloaded.
# [System ARGV] ['launch.py', '--preset', 'realistic', '--theme', 'dark', '--share', '--always-high-vram', '--all-in-fp16', '--output-path', '/content/drive/MyDrive/outputs']
# Python 3.10.12 (main, Nov  6 2024, 20:22:13) [GCC 11.4.0]
# Fooocus version: 2.5.5
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# Installing Prompt_translate requirement -> deep-translator
# model_type EPS
# UNet ADM Dimension 2816
# Prompt translate module AlekPet -> Loaded
# Config file created.
# [Wildcards] Refresh and Load 6/6 wildcards: animal, artist, color, extended-color, flower, nationality.
# IMPORTANT: You are using gradio version 3.41.2, however version 4.44.1 is available, please upgrade.
# --------
# Running on local URL:  http://127.0.0.1:7865
# Running on public URL: https://1712740e4c05b3cd87.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
